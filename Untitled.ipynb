# %%
from bs4 import BeautifulSoup
import requests

# %%
url = "https://www.statmuse.com/nba/player/stephen-curry-787"
result = requests.get(url) #getting an HTTP GET request for the url
print(result.text)
# Out:
# <!DOCTYPE html><html lang="en"> <head><meta charset="utf-8"><meta name="color-scheme" content="light only"><meta content="width=device-width, initial-scale=1.0" name="viewport"><meta name="format-detection" content="telephone=no"><meta name="generator" content="Astro v3.5.5"><meta name="apple-itunes-app" content="app-id=1234654160"><title>Stephen Curry - Golden State Warriors Point Guard | StatMuse</title><meta name="description" content="Stephen Curry has played 15 seasons for the Warriors. He has averaged 24.7 points, 6.4 assists and 4.7 rebounds in 912 regular-season games. He was selected to play in 9 All-Star games. He has won 2 MVP awards, 1 Finals MVP award and 4 NBA championships."><meta name="keywords" content="NBA basketball Stephen Curry career stats statistics"><meta property="fb:app_id" content="915991831757165"><meta property="og:site_name" content="StatMuse"><meta property="og:title" content="Stephen Curry - Golden State Warriors Point Guard | StatMuse"><meta property=
# ...

# %%
doc = BeautifulSoup(result.text,"html.parser")
print(doc.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# ...
